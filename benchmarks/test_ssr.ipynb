# %%
import logging
logging.captureWarnings(True)
import warnings
warnings.filterwarnings('ignore')
from ucc.ssr.main import process_quantum_circuits
# Out:
# WARNING: Could not find system address(es):
# [Errno 8] nodename nor servname provided, or not known

# %%
# method_AG = ['Google Sycamore']
rows = 5
cols = 4
method_AG = [f'Grid {rows}*{cols}']
# method_AG = ['IBM Heron']
# method_AG = ['IBM Rochester']

input_folder = "/Users/mistywahl/Documents/GitHub/ucc/ucc/ssr/Data/RevLib/Sabre/"

output_xlsx =  f"/Users/mistywahl/Documents/GitHub/ucc/ucc/ssr/Results/ucc_test/{str(method_AG).replace(" ", "")}.xlsx"

output_qasm_folder = "/Users/mistywahl/Documents/GitHub/ucc/ucc/ssr/Results/ucc_test/qasm"

# %%
# %%capture my_warnings
process_quantum_circuits(input_folder, method_AG, output_xlsx, output_qasm_folder)
# Out:
# WARNING: Could not find system address(es):
# [Errno 8] nodename nor servname provided, or not known
# WARNING: Could not find system address(es):
# [Errno 8] nodename nor servname provided, or not known
# WARNING: Could not find system address(es):
# [Errno 8] nodename nor servname provided, or not known
# WARNING: Could not find system address(es):
# [Errno 8] nodename nor servname provided, or not known
# WARNING: Could not find system address(es):
# [Errno 8] nodename nor servname provided, or not known
# WARNING: Could not find system address(es):
# [Errno 8] nodename nor servname provided, or not known
# WARNING: Could not find system address(es):
# [Errno 8] nodename nor servname provided, or not known
# WARNING: Could not find system address(es):
# [Errno 8] nodename nor servname provided, or not known
# ...
